# %%
# Import necessary libraries
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# Load test module for sanity check
from test_utils import test

# %% [markdown]
# Data Generation
# ===

# %%
num_samples, num_features = 10, 5

# %%
np.random.seed(10)
data = np.random.rand(num_samples, num_features)

# %% [markdown]
# Solution
# ===

# %%
print(data)

# %%
def standardize(x):
    """Standardize the input data x

    Args:
        x: numpy array of shape=(num_samples, num_features)

    Returns:
        standardized data, shape=(num_samples, num_features)

    >>> standardize(np.array([[1, 2], [3, 4], [5, 6]]))
    array([[-1.22474487, -1.22474487],
           [ 0.        ,  0.        ],
           [ 1.22474487,  1.22474487]])
    """
    # ***************************************************
    # INSERT YOUR CODE HERE
    # TODO: standardize input data x
    # ***************************************************

    std_data = (x - np.mean(x, axis=0))/np.std(x, axis = 0)

    #axis=0 → on descend le long des lignes (opération sur chaque colonne)
    #axis=1 → on traverse le long des colonnes (opération sur chaque ligne)

    ##raise NotImplementedError
    return std_data


test(standardize)
# Out:
# ✅ Your `standardize` passed 1 tests.

# %%
data = np.array([[1, 2], [3, 4], [5, 6]])

std_data = standardize(data)
print(std_data, "\n\n", np.mean(std_data, axis=0), "\n\n", np.std(std_data, axis=0))
# Out:
# [[-1.22474487 -1.22474487]
#  [ 0.          0.        ]
#  [ 1.22474487  1.22474487]]
#
#  [0. 0.]
#
#  [1. 1.]
